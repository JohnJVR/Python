# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("E:\excelr\data science\data sets\data sets_BA\Computer_Data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0           1   1499     25   80    4      14  no    no     yes   94      1
# 1           2   1795     33   85    2      14  no    no     yes   94      1
# 2           3   1595     25  170    4      15  no    no     yes   94      1
# 3           4   1849     25  170    8      14  no    no      no   94      1
# 4           5   3295     33  340   16      14  no    no     yes   94      1

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'price', 'speed', 'hd', 'ram', 'screen', 'cd', 'multi',
#        'premium', 'ads', 'trend'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Unnamed: 0        price        speed           hd          ram  \
# count  6259.000000  6259.000000  6259.000000  6259.000000  6259.000000
# mean   3130.000000  2219.576610    52.011024   416.601694     8.286947
# std    1806.961999   580.803956    21.157735   258.548445     5.631099
# min       1.000000   949.000000    25.000000    80.000000     2.000000
# 25%    1565.500000  1794.000000    33.000000   214.000000     4.000000
# 50%    3130.000000  2144.000000    50.000000   340.000000     8.000000
# 75%    4694.500000  2595.000000    66.000000   528.000000     8.000000
# max    6259.000000  5399.000000   100.000000  2100.000000    32.000000
#
#             screen          ads        trend
# count  6259.000000  6259.000000  6259.000000
# mean     14.608723   221.301007    15.926985
# std       0.905115    74.835284     7.873984
# min      14.000000    39.000000     1.000000
# 25%      14.000000   162.500000    10.000000
# 50%      14.000000   246.000000    16.000000
# ...

# %%
data.median()
# Out:
# Unnamed: 0    3130.0
# price         2144.0
# speed           50.0
# hd             340.0
# ram              8.0
# screen          14.0
# ads            246.0
# trend           16.0
# dtype: float64

# %%
data.mean()
# Out:
# Unnamed: 0    3130.000000
# price         2219.576610
# speed           52.011024
# hd             416.601694
# ram              8.286947
# screen          14.608723
# ads            221.301007
# trend           15.926985
# dtype: float64

# %%
data.skew()
# Out:
# Unnamed: 0    0.000000
# price         0.711725
# speed         0.657008
# hd            1.378019
# ram           1.386202
# screen        1.634008
# ads          -0.553328
# trend         0.236669
# dtype: float64

# %%
data.kurt()
# Out:
# Unnamed: 0   -1.200000
# price         0.730417
# speed        -0.275453
# hd            2.452456
# ram           1.462250
# screen        1.851825
# ads          -0.539843
# trend        -0.674134
# dtype: float64

# %%
plt.boxplot(data['price']);plt.ylabel("PRICE")
# Out:
# Text(0, 0.5, 'PRICE')

# %%
plt.boxplot(data['price'],0,'bo',1); plt.ylabel("PRICE") # bo is for the colour. 1 or 0 is for Horizontal and vertical
# Out:
# Text(0, 0.5, 'PRICE')

# %%
sns.pairplot(data.iloc[:,1:7])

# %%
data.price.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.speed.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.hd.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.ram.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.screen.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.cd.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.multi.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.premium.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.ads.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.trend.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.groupby(data.ram).median()
# Out:
#      Unnamed: 0   price  speed      hd  screen    ads  trend
# ram
# 2        1959.5  1695.0   33.0   107.0    14.0  267.0   11.0
# 4        2703.0  1799.0   33.0   214.0    14.0  249.0   14.0
# 8        3434.0  2220.0   66.0   426.0    14.0  225.0   17.0
# 16       3349.0  2744.0   66.0   528.0    15.0  246.0   16.0
# 24       5089.0  2894.0   66.0  1000.0    15.0  163.0   24.0
# 32       6203.5  3183.5   75.0  1600.0    15.0   39.0   34.0

# %%
data.ram.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='ram'>

# %%
data.screen.groupby(data.ram).plot(kind="bar")
# Out:
# ram
# 2     AxesSubplot(0.125,0.125;0.775x0.755)
# 4     AxesSubplot(0.125,0.125;0.775x0.755)
# 8     AxesSubplot(0.125,0.125;0.775x0.755)
# 16    AxesSubplot(0.125,0.125;0.775x0.755)
# 24    AxesSubplot(0.125,0.125;0.775x0.755)
# 32    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: screen, dtype: object

# %%
data.ram.groupby(data.cd).plot(kind="bar")
# Out:
# cd
# no     AxesSubplot(0.125,0.125;0.775x0.755)
# yes    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: ram, dtype: object

# %%
data.plot.box()
# Out:
# <AxesSubplot:>

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.plot.bar(figsize=(20,10))
# Out:
# <AxesSubplot:>
